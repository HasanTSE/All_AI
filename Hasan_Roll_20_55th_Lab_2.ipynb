# %% [markdown]
# 1.Read an image using Google colab.

# %%
import numpy as np

# %%
import cv2

# %% [markdown]
# 2.Show an image.

# %%
from google.colab.patches import cv2_imshow
img=cv2.imread("/content/lion2.jpg")

# %%
cv2_imshow(img)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-d0027ef4e25a> in <cell line: 1>()
# ----> 1 cv2_imshow(img)
#
# /usr/local/lib/python3.10/dist-packages/google/colab/patches/__init__.py in cv2_imshow(a)
#      16       (N, M, 4) is an NxM BGRA color image.
#      17   """
# ---> 18   a = a.clip(0, 255).astype('uint8')
#      19   # cv2 stores colors as BGR; convert to RGB
#      20   if a.ndim == 3:
#
# AttributeError: 'NoneType' object has no attribute 'clip'

# %%
resize_image = cv2.resize(img, (500,200))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-5df69fe84caf> in <cell line: 1>()
# ----> 1 resize_image = cv2.resize(img, (500,200))
#
# NameError: name 'cv2' is not defined

# %%
cv2_imshow(resize_image)
# Out:
# <PIL.Image.Image image mode=RGB size=500x200 at 0x7F3DD251B4F0>

# %% [markdown]
# 2.1 Save an input image as an output image.

# %%
cv2.imwrite("outputLion.jpg",img)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-10-f3a9f91dd12a> in <cell line: 1>()
# ----> 1 cv2.imwrite("outputLion.jpg",img)
#
# error: OpenCV(4.7.0) /io/opencv/modules/imgcodecs/src/loadsave.cpp:783: error: (-215:Assertion failed) !_img.empty() in function 'imwrite'

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# 2.2 Find the elements of an image

# %%
total_number_of_elements= img.size
print(total_number_of_elements)
# Out:
# 16588800

# %% [markdown]
# 2.3 Find a rgb value of a pixel

# %%
(b, g, r) = img[100, 100]
print("Pixel at (100, 100) - Red: {}, Green: {}, Blue: {}".format(r,g,b))
# Out:
# Pixel at (100, 100) - Red: 93, Green: 67, Blue: 50

# %% [markdown]
# 2.4 Change the color of a portion of an image.

# %%
resize_image[0:150, 0:300] = [255,255,0]
cv2_imshow(resize_image)
# Out:
# <PIL.Image.Image image mode=RGB size=500x200 at 0x7F3DD18FDF90>

# %% [markdown]
# 2.5 Convert a bar image to gray a scale image.

# %%
image_gray = cv2.cvtColor(resize_image, cv2.COLOR_BGR2GRAY)
cv2_imshow(image_gray)
# Out:
# <PIL.Image.Image image mode=L size=500x200 at 0x7F3DD18FFF70>
