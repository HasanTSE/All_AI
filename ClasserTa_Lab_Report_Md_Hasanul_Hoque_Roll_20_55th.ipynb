# %% [markdown]
# 1. Read an Image.

# %%
import numpy as np

# %%
import cv2

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# 2. Show an image.

# %%
from google.colab.patches import cv2_imshow

# %%
img = cv2.imread("/content/ocean.jpg")

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=612x408 at 0x7C8671212C50>

# %% [markdown]
# 3. Convert RGB to GRAY.

# %%
img = cv2. imread("/content/ocean.jpg",0)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=L size=612x408 at 0x7C8666B2D180>

# %% [markdown]
# 4. Find data type, height, width channel of an image.

# %%
print(img.dtype)
# Out:
# uint8

# %%
print('Height', img.shape[0])
# Out:
# Height 408

# %% [markdown]
# Width

# %%
print(img.shape[1])
# Out:
# 612

# %% [markdown]
# Channels

# %%
print(img.shape[2])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-49-598de9624225> in <cell line: 1>()
# ----> 1 print(img.shape[2])
#
# IndexError: tuple index out of range

# %% [markdown]
# 5. Resized an image.

# %%
resize_img = cv2.resize(img,(400,400))
cv2_imshow(resize_img)
# Out:
# <PIL.Image.Image image mode=L size=400x400 at 0x7AA8ED85AE00>

# %% [markdown]
# 6. Save Output of an Image.

# %%
cv2.imwrite("outputLion.jpg",img)
# Out:
# True

# %% [markdown]
# 7. Find the total numbe of elements of an image.

# %%
total_number_of_elements = img.size
print(total_number_of_elements)
# Out:
# 172120

# %% [markdown]
# 8. Find a RGB of a pixel.

# %%
(b, g, r) = img[100, 100]
print("Pixel at (100, 100) - Red: {}, Green: {}, Blue: {}".format(r,g,b))
# Out:
# Pixel at (100, 100) - Red: 2, Green: 149, Blue: 227

# %% [markdown]
# 9. Colour resized of an image.

# %% [markdown]
# 10. RGB to gray using function.

# %% [markdown]
# 11. Inverse image

# %%
img_inv = 255 -img

# %%
cv2_imshow(img_inv)
# Out:
# <PIL.Image.Image image mode=L size=612x408 at 0x7C86AC9AE860>

# %% [markdown]
# 12. Transformation, To decrease the lightness of gray scale image.

# %%
im3 = (100.0/255)*img_inv + 100
cv2_imshow(im3)
# Out:
# <PIL.Image.Image image mode=L size=612x408 at 0x7C8671212F50>

# %%
import matplotlib.pyplot as plt
plt.hist(img_inv.ravel(),bins = 256,range = [0,256])
plt.show()

# %%
import matplotlib.pyplot as plt
plt.hist(im3.ravel(),bins = 256,range = [0,256])
plt.show()

# %%
import matplotlib.pyplot as plt
plt.hist(img.ravel(),bins = 256,range = [0,256])
plt.show()
