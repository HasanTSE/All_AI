# %% [markdown]
# 1. Read an Image.

# %%
import numpy as np

# %%
import cv2

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# 2. Show an image.

# %%
from google.colab.patches import cv2_imshow

# %%
img = cv2.imread("/content/ocean.jpg")

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=520x331 at 0x7AA8ED859450>

# %% [markdown]
# 3. Convert RGB to GRAY.

# %%
img = cv2. imread("/content/ocean.jpg",0)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=L size=520x331 at 0x7AA8ED859FC0>

# %% [markdown]
# 4. Find data type, height, width channel of an image.

# %%
print(img.dtype)
# Out:
# uint8

# %%
print('Height', img.shape[0])
# Out:
# Height 331

# %% [markdown]
# Width

# %%
print(img.shape[1])
# Out:
# 520

# %% [markdown]
# Channels

# %%
print(img.shape[2])
# Out:
# 3

# %% [markdown]
# 5. Resized an image.

# %%
resize_img = cv2.resize(img,(400,400))
cv2_imshow(resize_img)
# Out:
# <PIL.Image.Image image mode=L size=400x400 at 0x7AA8ED85AE00>

# %% [markdown]
# 6. Save Output of an Image.

# %%
cv2.imwrite("outputLion.jpg",img)
# Out:
# True

# %% [markdown]
# 7. Find the total numbe of elements of an image.

# %%
total_number_of_elements = img.size
print(total_number_of_elements)
# Out:
# 172120

# %% [markdown]
# 8. Find a RGB of a pixel.

# %%
(b, g, r) = img[100, 100]
print("Pixel at (100, 100) - Red: {}, Green: {}, Blue: {}".format(r,g,b))
# Out:
# Pixel at (100, 100) - Red: 2, Green: 149, Blue: 227

# %% [markdown]
# 9. Colour resized of an image.

# %%
resize_img[0:150, 0:300] = [0,255,0]
cv2_imshow(resize_img)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-133-746a7ae7aec7> in <cell line: 1>()
# ----> 1 resize_img[0:150, 0:300] = [0,255,0]
#       2 cv2_imshow(resize_img)
#
# ValueError: could not broadcast input array from shape (3,) into shape (150,300)

# %% [markdown]
# 10. RGB to gray using function.

# %%
img_gray = cv2.cvtColor(resize_img, cv2.COLOR_BGR2GRAY)
cv2_imshow(img_gray)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-139-602abdb17dd2> in <cell line: 1>()
# ----> 1 img_gray = cv2.cvtColor(resize_img, cv2.COLOR_BGR2GRAY)
#       2 cv2_imshow(img_gray)
#
# error: OpenCV(4.7.0) /io/opencv/modules/imgproc/src/color.simd_helpers.hpp:92: error: (-2:Unspecified error) in function 'cv::impl::{anonymous}::CvtHelper<VScn, VDcn, VDepth, sizePolicy>::CvtHelper(cv::InputArray, cv::OutputArray, int) [with VScn = cv::impl::{anonymous}::Set<3, 4>; VDcn = cv::impl::{anonymous}::Set<1>; VDepth = cv::impl::{anonymous}::Set<0, 2, 5>; cv::impl::{anonymous}::SizePolicy sizePolicy = cv::impl::<unnamed>::NONE; cv::InputArray = const cv::_InputArray&; cv::OutputArray = const cv::_OutputArray&]'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 1

# %%
im2 = 255 - img_gray
cv2_imshow(im2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-140-715646afd6f6> in <cell line: 1>()
# ----> 1 im2 = 255 - img_gray
#       2 cv2_imshow(im2)
#
# NameError: name 'img_gray' is not defined
